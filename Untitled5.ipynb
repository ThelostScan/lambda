# %% [markdown]
# <a href="https://colab.research.google.com/github/ThelostScan/lambda/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# El codigo sugerido puede estar sujeto a licencia
print("------------------------------------------------------")
print("-----------PROGRAMA QUE CALCULA EL PREDIO-------------")
print("------------------------------------------------------")


_#Datos de entrada
print("Ingrese las 3 calificaciones del alumno  N1, N2 Y N3")
N1=int(input ("N1: "))
N2=int(input ("N2: "))
N3=int(input("N3  : "))

#proceso
promedio=(N1+N2+N3)/3

#Datos de salida
print("El promedio de alumno es: ", promedio)
# Out:
# ------------------------------------------------------
# -----------PROGRAMA QUE CALCULA EL PREDIO-------------
# ------------------------------------------------------
# Ingrese las 3 calificaciones del alumno  N1, N2 Y N3
# N1: 8
# N2: 6
# N3  : 10
# El promedio de alumno es:  8.0

# %%
print("PUNTAJE FINAL")
#Datos de entrada
print("Total de respuestas correctas")
respuestas_correctas = int(input())
print("Total de respuestas incorrectas")
respuestas_incorrectas = int(input())
print("Total de respuestas en blanco")
respuestas_en_blanco = int(input())
print("Puntaje final")

#Proceso
puntaje_final = (respuestas_correctas * 3) + (respuestas_incorrectas * -1) + (respuestas_en_blanco * 0)
#Datos de salida
print(puntaje_final)
# Out:
# PUNTAJE FINAL
# Total de respuestas correctas
# 4
# Total de respuestas incorrectas
# 6
# Total de respuestas en blanco
# 3
# Puntaje final
# 6

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 2, 0, 0.5])
plt.show()

# %%
# Importar el módulo pyplot con el alias plt
import matplotlib.pyplot as plt
# Crear la figura y los ejes
fig, ax = plt.subplots()
# Dibujar puntos
ax.scatter(x = [1, 2, 3], y = [3, 2, 1])
# Guardar el gráfico en formato png
plt.savefig('diagrama-dispersion.png')
# Mostrar el gráfico
plt.show()
